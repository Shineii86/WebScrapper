# %% [markdown]
# # 🚀 WebScrapperBot - Google Colab Setup
#
# Run the cells below to set up and run the bot in Google Colab for free.

# %%
# Clone the repository
# !git clone https://github.com/Shineii86/WebScrapper.git

# %%
# Install dependencies
# !pip install -qU -r /content/WebScrapper/requirements.txt

# %%
# Install Chrome and dependencies for browser-based scraping
# !apt-get update -qq
# !apt-get install -y -qq chromium-chromedriver chromium-browser
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
# Set your credentials below
BOT_TOKEN = 'YOUR_BOT_TOKEN'  # Get from @BotFather
API_ID = 'YOUR_API_ID'        # Get from https://my.telegram.org/apps
API_HASH = 'YOUR_API_HASH'    # Get from https://my.telegram.org/apps
CRAWL_LOG_CHANNEL = ''        # Optional: Channel ID for crawl logs

# %%
# Create .env file with credentials
with open('.env', 'w') as f:
    f.write(f"BOT_TOKEN={BOT_TOKEN}\n")
    f.write(f"API_ID={API_ID}\n")
    f.write(f"API_HASH={API_HASH}\n")
    f.write(f"CRAWL_LOG_CHANNEL={CRAWL_LOG_CHANNEL}\n")

print("✅ .env file created successfully!")

# %%
# Run the bot
# !cd /content/WebScrapper && python -m src.main
